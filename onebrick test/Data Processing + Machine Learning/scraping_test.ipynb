# %%
import requests

BASE_URL = 'https://fakestoreapi.com'

resp = requests.get(f"{BASE_URL}/products")
json_res =  resp.json()

number_of_elements = len(json_res)

i = 0
while i < number_of_elements:
   print(json_res[i]['title']) 
   print(json_res[i]['category'])
   print(json_res[i]['rating']['rate'])
   print("storeName")
   print(json_res[i]['price'])
   print(" ")
   i += 1
# Out:
# Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops
# men's clothing
# 3.9
# storeName
# 109.95
#
# Mens Casual Premium Slim Fit T-Shirts
# men's clothing
# 4.1
# storeName
# 22.3
#
# Mens Cotton Jacket
# men's clothing
# 4.7
# storeName
# 55.99
#
# Mens Casual Slim Fit
# men's clothing
# 2.1
# storeName
# 15.99
#
# John Hardy Women's Legends Naga Gold & Silver Dragon Station Chain Bracelet
# jewelery
# 4.6
# storeName
# 695
#
# Solid Gold Petite Micropave
# jewelery
# 3.9
# storeName
# 168
#
# White Gold Plated Princess
# jewelery
# 3
# storeName
# 9.99
#
# Pierced Owl Rose Gold Plated Stainless Steel Double
# jewelery
# 1.9
# storeName
# 10.99
#
# WD 2TB Elements Portable External Hard Drive - USB 3.0
# electronics
# 3.3
# storeName
# 64
#
# SanDisk SSD PLUS 1TB Internal SSD - SATA III 6 Gb/s
# electronics
# 2.9
# storeName
# 109
#
# Silicon Power 256GB SSD 3D NAND A55 SLC Cache Performance Boost SATA III 2.5
# electronics
# 4.8
# storeName
# 109
#
# WD 4TB Gaming Drive Works with Playstation 4 Portable External Hard Drive
# electronics
# 4.8
# storeName
# 114
#
# Acer SB220Q bi 21.5 inches Full HD (1920 x 1080) IPS Ultra-Thin
# electronics
# 2.9
# storeName
# 599
#
# Samsung 49-Inch CHG90 144Hz Curved Gaming Monitor (LC49HG90DMNXZA) – Super Ultrawide Screen QLED
# electronics
# 2.2
# storeName
# 999.99
#
# BIYLACLESEN Women's 3-in-1 Snowboard Jacket Winter Coats
# women's clothing
# 2.6
# storeName
# 56.99
#
# Lock and Love Women's Removable Hooded Faux Leather Moto Biker Jacket
# women's clothing
# 2.9
# storeName
# 29.95
#
# Rain Jacket Women Windbreaker Striped Climbing Raincoats
# women's clothing
# 3.8
# storeName
# 39.99
#
# MBJ Women's Solid Short Sleeve Boat Neck V
# women's clothing
# 4.7
# storeName
# 9.85
#
# Opna Women's Short Sleeve Moisture
# women's clothing
# 4.5
# storeName
# 7.95
#
# DANVOUY Womens T Shirt Casual Cotton Short
# women's clothing
# 3.6
# storeName
# 12.99

# %%
resp = requests.get(f"{BASE_URL}/products")
json_res =  resp.json()


df = pd.DataFrame(json_res)


df.groupby(['category']).groups.keys()
# Out:
#     id  ...                       rating
# 0    1  ...  {'rate': 3.9, 'count': 120}
# 1    2  ...  {'rate': 4.1, 'count': 259}
# 2    3  ...  {'rate': 4.7, 'count': 500}
# 3    4  ...  {'rate': 2.1, 'count': 430}
# 4    5  ...  {'rate': 4.6, 'count': 400}
# 5    6  ...   {'rate': 3.9, 'count': 70}
# 6    7  ...    {'rate': 3, 'count': 400}
# 7    8  ...  {'rate': 1.9, 'count': 100}
# 8    9  ...  {'rate': 3.3, 'count': 203}
# 9   10  ...  {'rate': 2.9, 'count': 470}
# 10  11  ...  {'rate': 4.8, 'count': 319}
# 11  12  ...  {'rate': 4.8, 'count': 400}
# 12  13  ...  {'rate': 2.9, 'count': 250}
# 13  14  ...  {'rate': 2.2, 'count': 140}
# 14  15  ...  {'rate': 2.6, 'count': 235}
# 15  16  ...  {'rate': 2.9, 'count': 340}
# 16  17  ...  {'rate': 3.8, 'count': 679}
# 17  18  ...  {'rate': 4.7, 'count': 130}
# 18  19  ...  {'rate': 4.5, 'count': 146}
# 19  20  ...  {'rate': 3.6, 'count': 145}
#
# [20 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import plotly.express as px

#Libraries for preprocessing
from gensim.parsing.preprocessing import remove_stopwords
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import webcolors

#Download once if using NLTK for preprocessing
import nltk
nltk.download('punkt')

#Libraries for vectorisation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
from fuzzywuzzy import fuzz

#Libraries for clustering
from sklearn.cluster import KMeans

resp = requests.get(f"{BASE_URL}/products")
json_res =  resp.json()


df = pd.DataFrame(json_res)

text1 = df['title']

#Remove stopwords, punctuation and numbers
text2 = [remove_stopwords(x)\
        .translate(str.maketrans('','',string.punctuation))\
        .translate(str.maketrans('','',string.digits))\
        for x in text1]

text2
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Fjallraven  Foldsack No  Backpack Fits  Laptops',
#  'Mens Casual Premium Slim Fit TShirts',
#  'Mens Cotton Jacket',
#  'Mens Casual Slim Fit',
#  'John Hardy Womens Legends Naga Gold  Silver Dragon Station Chain Bracelet',
#  'Solid Gold Petite Micropave',
#  'White Gold Plated Princess',
#  'Pierced Owl Rose Gold Plated Stainless Steel Double',
#  'WD TB Elements Portable External Hard Drive  USB ',
#  'SanDisk SSD PLUS TB Internal SSD  SATA III  Gbs',
#  'Silicon Power GB SSD D NAND A SLC Cache Performance Boost SATA III ',
#  'WD TB Gaming Drive Works Playstation  Portable External Hard Drive',
#  'Acer SBQ bi  inches Full HD  x  IPS UltraThin',
#  'Samsung Inch CHG Hz Curved Gaming Monitor LCHGDMNXZA – Super Ultrawide Screen QLED',
#  'BIYLACLESEN Womens in Snowboard Jacket Winter Coats',
#  'Lock Love Womens Removable Hooded Faux Leather Moto Biker Jacket',
#  'Rain Jacket Women Windbreaker Striped Climbing Raincoats',
#  'MBJ Womens Solid Short Sleeve Boat Neck V',
#  'Opna Womens Short Sleeve Moisture',
#  'DANVOUY Womens T Shirt Casual Cotton Short']

# %%
#make lower case
def stemSentence(sentence):
    porter = PorterStemmer()
    token_words = word_tokenize(sentence)
    stem_sentence = [porter.stem(word) for word in token_words]
    return ' '.join(stem_sentence)

text3 = pd.Series([stemSentence(x) for x in text2])

text3
# Out:
# 0            fjallraven foldsack No backpack fit laptop
# 1                    men casual premium slim fit tshirt
# 2                                     men cotton jacket
# 3                                   men casual slim fit
# 4     john hardi women legend naga gold silver drago...
# 5                             solid gold petit micropav
# 6                             white gold plate princess
# 7       pierc owl rose gold plate stainless steel doubl
# 8           WD TB element portabl extern hard drive usb
# 9             sandisk ssd plu TB intern ssd sata iii gb
# 10    silicon power GB ssd D nand A slc cach perform...
# 11    WD TB game drive work playstat portabl extern ...
# 12              acer sbq bi inch full HD x ip ultrathin
# 13    samsung inch chg Hz curv game monitor lchgdmnx...
# 14    biylaclesen women in snowboard jacket winter coat
# 15    lock love women remov hood faux leather moto b...
# 16    rain jacket women windbreak stripe climb raincoat
# 17              mbj women solid short sleev boat neck V
# 18                       opna women short sleev moistur
# 19            danvouy women T shirt casual cotton short
# dtype: object

# %%
#counts the occurrences of words in a document.
vectorizer_cv = CountVectorizer(analyzer='word')
X_cv = vectorizer_cv.fit_transform(text3)
X_cv
# Out:
# <20x106 sparse matrix of type '<class 'numpy.int64'>'
# 	with 144 stored elements in Compressed Sparse Row format>

# %%
# Kmeans clutering
kmeans = KMeans(n_clusters=10)
kmeans.fit(X_cv)
result = pd.concat([text1,pd.DataFrame(X_cv.toarray(),columns=vectorizer_cv.get_feature_names())],axis=1)
result['cluster'] = kmeans.predict(X_cv)

result[['title','cluster']]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#                                                 title  cluster
# 0   Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...        6
# 1              Mens Casual Premium Slim Fit T-Shirts         6
# 2                                  Mens Cotton Jacket        6
# 3                                Mens Casual Slim Fit        6
# 4   John Hardy Women's Legends Naga Gold & Silver ...        8
# 5                        Solid Gold Petite Micropave         2
# 6                          White Gold Plated Princess        2
# 7   Pierced Owl Rose Gold Plated Stainless Steel D...        2
# 8   WD 2TB Elements Portable External Hard Drive -...        3
# 9   SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...        4
# 10  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...        4
# 11  WD 4TB Gaming Drive Works with Playstation 4 P...        3
# 12  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...        9
# 13  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...        5
# 14  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...        0
# 15  Lock and Love Women's Removable Hooded Faux Le...        7
# 16  Rain Jacket Women Windbreaker Striped Climbing...        0
# 17        MBJ Women's Solid Short Sleeve Boat Neck V         1
# 18                 Opna Women's Short Sleeve Moisture        1
# 19         DANVOUY Womens T Shirt Casual Cotton Short        1
